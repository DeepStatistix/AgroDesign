# %%
import pandas as pd
from agrodesign.experiment import Experiment

df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\crd.csv")

result = Experiment(df,"Yield").crd("Treatment").run()

result
print(result)
result.summary()
result.plot()
result.export("outputs/crd")

# %%
import pandas as pd
from agrodesign.experiment import Experiment

df = pd.read_csv(r"D:\Git Projects\AGRODESIGN\examples\data\rcbd.csv")

result = Experiment(df,"Yield").rcbd("Variety","Block").run()

result
print(result)
result.summary()
result.plot()
result.export("outputs/rcbd")

# %%
import pandas as pd
from agrodesign.experiment import Experiment

df = pd.read_csv(r"D:\Git Projects\AGRODESIGN\examples\data\factorial.csv")

result = Experiment(df,"Yield").factorial(["Nitrogen","Spacing"]).run()

result
print(result)
result.summary()
result.plot()
result.export("outputs/factorial")

# %%
import pandas as pd
from agrodesign.experiment import Experiment

df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\splitplot.csv")

result = Experiment(df,"Yield").split_plot("Irrigation","Variety","Block").run()

result
print(result)
result.summary()
result.plot()
result.export("outputs/splitplot")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# C:\Windows\Temp\ipykernel_42632\71812956.py:4: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\splitplot.csv")
# ...
# AGRODESIGN ANALYSIS
# ...
#
# SPLIT ANALYSIS
# Response variable: Yield
# Post-hoc test: Tukey HSD (α = 0.05)
#
# --------------------------------------------------
# ANOVA TABLE
# --------------------------------------------------
# Source                      DF          MS       F p-value Significance
# C(Block)                   2.0    8.111111    73.0  <0.001          ***
# C(Irrigation)              2.0  626.333333  5637.0  <0.001          ***
# C(Variety)                 2.0   90.333333   813.0  <0.001          ***
# C(Block):C(Irrigation)     4.0    0.111111     1.0   0.445           ns
# C(Irrigation):C(Variety)   4.0    1.333333    12.0  <0.001          ***
# ...

# %%
import pandas as pd
from agrodesign.experiment import Experiment

df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\mixed.csv")

result = Experiment(df,"Yield").mixed(fixed=["Treatment"], random=["Block"]).run()

result
print(result)
result.summary()
result.plot()
result.export("outputs/mixed")
# Out:
# ...
# AGRODESIGN ANALYSIS
# ...
#
# MIXED MODEL ANALYSIS
# Response variable: Yield
# Post-hoc test: Tukey HSD (α = 0.05)
#
# Variance components:
# --------------------------------
# Block (random)     1.22
# Residual (random)     0.44
#
# BLUPs (Treatment effects)
# --------------------------------
# T3    54.5
# T2    48.5
# T1    41.5
#
# Normality test (Shapiro-Wilk): p = 0.30
# Residuals: Normally distributed
#
# --------------------------------------------------
# FINAL RECOMMENDATION
# --------------------------------------------------
# After adjusting for block-to-block variability,
# treatment T3 consistently produced superior yield.
#
# Farmers should adopt treatment T3 across environments.
#
# Expected improvement: +31% compared to T1
#
# ...
#
# ================ AGRONOMIC INTERPRETATION ================
#
# After adjusting for block-to-block variability,
# treatment T3 consistently produced superior yield.
#
# Farmers should adopt treatment T3 across environments.
#
# ...

# %%
import pandas as pd
from agrodesign.experiment import Experiment

df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\gxe.csv")

result = Experiment(df,"Yield").gxe("Genotype","Environment","Rep").run()

result
print(result)
result.summary()
result.plot()
result.export("outputs/gxe")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# C:\Windows\Temp\ipykernel_42632\1256542423.py:4: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\gxe.csv")
# ...
# AGRODESIGN ANALYSIS
# ...
#
# GxE ANALYSIS
# Response variable: Yield
# Post-hoc test: Tukey HSD (α = 0.05)
#
# --------------------------------------------------
# ANOVA TABLE
# --------------------------------------------------
# Source                        DF          MS           F p-value Significance
# C(Genotype)                  3.0  364.458333  728.916667  <0.001          ***
# C(Environment)               3.0   42.458333   84.916667  <0.001          ***
# C(Genotype):C(Environment)   9.0    0.458333    0.916667   0.535           ns
# Residual                    16.0    0.500000         NaN     nan           ns
#
# Highest significant effect: Genotype
#
# Interpretation rule:
# ...

# %%
import pandas as pd
from agrodesign.experiment import Experiment

df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\grouped.csv")

result = Experiment(df,"Yield").by("Year").rcbd("Variety","Block").run()

result            # combined snapshot
print(result)     # full report per year
result.summary()  # combined interpretation
result.plot()
result.export("outputs/grouped")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# C:\Windows\Temp\ipykernel_42632\1698896636.py:4: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\grouped.csv")
# ...
# GROUPED ANALYSIS REPORT
# ...
#
# ### Year = 2021
# ...
# AGRODESIGN ANALYSIS
# ...
#
# RCBD ANALYSIS
# Response variable: Yield
# Post-hoc test: Tukey HSD (α = 0.05)
#
# --------------------------------------------------
# ANOVA TABLE
# --------------------------------------------------
# Source       DF          MS      F p-value Significance
# C(Variety)  3.0  106.666667  640.0  <0.001          ***
# C(Block)    3.0    6.166667   37.0  <0.001          ***
# Residual    9.0    0.166667    NaN     nan           ns
#
# Highest significant effect: Variety
#
# Interpretation rule:
# No interaction detected → interpret main effects
#
# --------------------------------------------------
# POST HOC TEST CRITICAL VALUES
# ...

# %%
import pandas as pd
from agrodesign.experiment import Experiment

df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\multitrait.csv")

result = Experiment(df,["Yield","Height"]).rcbd("Variety","Block").run()

result            # collection snapshot
print(result)     # report per trait
result.summary()  # overall best variety
result.plot()
result.export("outputs/multitrait")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# C:\Windows\Temp\ipykernel_42632\3553086738.py:4: SyntaxWarning: invalid escape sequence '\G'
#   df = pd.read_csv("D:\Git Projects\AGRODESIGN\examples\data\multitrait.csv")
# ...
# GROUPED ANALYSIS REPORT
# ...
#
# ### Response = Yield
# ...
# AGRODESIGN ANALYSIS
# ...
#
# RCBD ANALYSIS
# Response variable: Yield
# Post-hoc test: Tukey HSD (α = 0.05)
#
# --------------------------------------------------
# ANOVA TABLE
# --------------------------------------------------
# Source       DF          MS      F p-value Significance
# C(Variety)  3.0  106.666667  320.0  <0.001          ***
# C(Block)    3.0    5.666667   17.0  <0.001          ***
# Residual    9.0    0.333333    NaN     nan           ns
#
# Highest significant effect: Variety
#
# Interpretation rule:
# No interaction detected → interpret main effects
#
# --------------------------------------------------
# POST HOC TEST CRITICAL VALUES
# ...
